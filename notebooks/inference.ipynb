# %% [markdown]
# # SQLDepth Inference
# In this notebook we show a basic inference.

# %%
from __future__ import absolute_import, division, print_function

import os
import glob
import numpy as np
import PIL.Image as pil
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True
import matplotlib as mpl
import matplotlib.image as mpimg
from matplotlib import pyplot as plt
import matplotlib.cm as cm
import torch
from torchvision import transforms


from src.models.SQLDepth import SQLdepth
from src.inference.test import test_simple
from src.config.conf import ResNet50_320x1024_Conf, ResNet50_192x640_Conf, ConvNeXtLarge_320x1024_Conf, Effb5_320x1024_Conf

# %%
input_image_path='/home/ANT.AMAZON.COM/grigiono/Desktop/SQLdepth/src/inference/input_images/img2.png'
input_image=mpimg.imread(input_image_path)
imgplot = plt.imshow(input_image)
plt.show()

# %% [markdown]
# ## ResNet50 - 320x1024 model inference

# %%
conf = ResNet50_320x1024_Conf().conf # ResNet50_320x1024_Conf, ResNet50_192x640_Conf, ConvNeXtLarge_320x1024_Conf, Effb5_320x1024_Conf

test_simple(conf)
# Out:
# -> Loading pretrained encoder from  /home/ANT.AMAZON.COM/grigiono/Desktop/SQLdepth/src/pretrained/KITTI_ResNet50_320x1024_models
# -> Loading pretrained depth decoder from  /home/ANT.AMAZON.COM/grigiono/Desktop/SQLdepth/src/pretrained/KITTI_ResNet50_320x1024_models
# -> Predicting on 1 test image(s)
#    Processed 1 of 1 images - saved predictions to:
#                                          /home/ANT.AMAZON.COM/grigiono/Desktop/SQLdepth/src/inference/output_images
# -> Done!

# %%
output_depth_path='/home/ANT.AMAZON.COM/grigiono/Desktop/SQLdepth/src/inference/output_images/img2_color_depth_map.jpeg'
output_depth=mpimg.imread(output_depth_path)
imgplot = plt.imshow(output_depth)
plt.show()

# %%
print("output_detph_map.min(): ", output_depth.min())
print("output_detph_map.max(): ", output_depth.max())
# Out:
# output_detph_map.min():  0
# output_detph_map.max():  255

# %%
output_depth_path='/home/ANT.AMAZON.COM/grigiono/Desktop/SQLdepth/src/inference/output_images/img2_uint16_depth_map.png'
output_depth=mpimg.imread(output_depth_path)
imgplot = plt.imshow(output_depth, cmap='gray')
plt.show()

# %%
print("output_detph_map.min(): ", output_depth.min())
print("output_detph_map.max(): ", output_depth.max())
# Out:
# output_detph_map.min():  0.01608301
# output_detph_map.max():  0.9541161

# %% [markdown]
# ## ResNet50 - 192x640 model inference

# %%
# !rm /home/ANT.AMAZON.COM/grigiono/Desktop/SQLdepth/src/inference/output_images/img2_color_depth_map.jpeg
# !rm /home/ANT.AMAZON.COM/grigiono/Desktop/SQLdepth/src/inference/output_images/img2_uint16_depth_map.png

# %%
conf = ResNet50_192x640_Conf().conf # ResNet50_320x1024_Conf, ResNet50_192x640_Conf, ConvNeXtLarge_320x1024_Conf, Effb5_320x1024_Conf

test_simple(conf)
# Out:
# -> Loading pretrained encoder from  /home/ANT.AMAZON.COM/grigiono/Desktop/SQLdepth/src/pretrained/KITTI_ResNet50_192x640_models
# -> Loading pretrained depth decoder from  /home/ANT.AMAZON.COM/grigiono/Desktop/SQLdepth/src/pretrained/KITTI_ResNet50_192x640_models
# -> Predicting on 1 test image(s)
#    Processed 1 of 1 images - saved predictions to:
#                                          /home/ANT.AMAZON.COM/grigiono/Desktop/SQLdepth/src/inference/output_images
# -> Done!

# %%
output_depth_path='/home/ANT.AMAZON.COM/grigiono/Desktop/SQLdepth/src/inference/output_images/img2_color_depth_map.jpeg'
output_depth=mpimg.imread(output_depth_path)
imgplot = plt.imshow(output_depth)
plt.show()

# %%
output_depth_path='/home/ANT.AMAZON.COM/grigiono/Desktop/SQLdepth/src/inference/output_images/img2_uint16_depth_map.png'
output_depth=mpimg.imread(output_depth_path)
imgplot = plt.imshow(output_depth, cmap='gray')
plt.show()

# %% [markdown]
# ## EfficientNetB5 - 320x1024 model inference

# %%
# !rm /home/ANT.AMAZON.COM/grigiono/Desktop/SQLdepth/src/inference/output_images/img2_color_depth_map.jpeg
# !rm /home/ANT.AMAZON.COM/grigiono/Desktop/SQLdepth/src/inference/output_images/img2_uint16_depth_map.png

# %%
conf = Effb5_320x1024_Conf().conf # ResNet50_320x1024_Conf, ResNet50_192x640_Conf, ConvNeXtLarge_320x1024_Conf, Effb5_320x1024_Conf

test_simple(conf)
# Out:
# -> Loading pretrained encoder from  /home/ANT.AMAZON.COM/grigiono/Desktop/SQLdepth/src/pretrained/KITTI_EfficientNetB5_320x1024_models
# -> Loading pretrained depth decoder from  /home/ANT.AMAZON.COM/grigiono/Desktop/SQLdepth/src/pretrained/KITTI_EfficientNetB5_320x1024_models
# -> Predicting on 1 test image(s)
#    Processed 1 of 1 images - saved predictions to:
#                                          /home/ANT.AMAZON.COM/grigiono/Desktop/SQLdepth/src/inference/output_images
# -> Done!

# %%
output_depth_path='/home/ANT.AMAZON.COM/grigiono/Desktop/SQLdepth/src/inference/output_images/img2_color_depth_map.jpeg'
output_depth=mpimg.imread(output_depth_path)
imgplot = plt.imshow(output_depth)
plt.show()

# %%
output_depth_path='/home/ANT.AMAZON.COM/grigiono/Desktop/SQLdepth/src/inference/output_images/img2_uint16_depth_map.png'
output_depth=mpimg.imread(output_depth_path)
imgplot = plt.imshow(output_depth, cmap='gray')
plt.show()

# %% [markdown]
# ## ConvNeXtLarge - 320x1024 model inference

# %%
# !rm /home/ANT.AMAZON.COM/grigiono/Desktop/SQLdepth/src/inference/output_images/img2_color_depth_map.jpeg
# !rm /home/ANT.AMAZON.COM/grigiono/Desktop/SQLdepth/src/inference/output_images/img2_uint16_depth_map.png

# %%
conf = ConvNeXtLarge_320x1024_Conf().conf # ResNet50_320x1024_Conf, ResNet50_192x640_Conf, ConvNeXtLarge_320x1024_Conf, Effb5_320x1024_Conf

test_simple(conf)
# Out:
# -> Loading pretrained encoder from  /home/ANT.AMAZON.COM/grigiono/Desktop/SQLdepth/src/pretrained/KITTI_ConvNeXt_Large_320x1024_models
# -> Loading pretrained depth decoder from  /home/ANT.AMAZON.COM/grigiono/Desktop/SQLdepth/src/pretrained/KITTI_ConvNeXt_Large_320x1024_models
# -> Predicting on 1 test image(s)
#    Processed 1 of 1 images - saved predictions to:
#                                          /home/ANT.AMAZON.COM/grigiono/Desktop/SQLdepth/src/inference/output_images
# -> Done!

# %%
output_depth_path='/home/ANT.AMAZON.COM/grigiono/Desktop/SQLdepth/src/inference/output_images/img2_color_depth_map.jpeg'
output_depth=mpimg.imread(output_depth_path)
imgplot = plt.imshow(output_depth)
plt.show()

# %%
output_depth_path='/home/ANT.AMAZON.COM/grigiono/Desktop/SQLdepth/src/inference/output_images/img2_uint16_depth_map.png'
output_depth=mpimg.imread(output_depth_path)
imgplot = plt.imshow(output_depth, cmap='gray')
plt.show()
